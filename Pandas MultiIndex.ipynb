# %%
# 출처:
https://blockchainstudy.tistory.com/45

# %%
import pandas as pd
import numpy as np 

df = pd.read_csv("C:\\Python\\Dataset\\titanic.csv")
df.head()
# Out:
#    Unnamed: 0  Survived  Pclass  \
# 0           0         0       3
# 1           1         1       1
# 2           2         1       3
# 3           3         1       1
# 4           4         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
# A quick introduction to MultiIndex
df.index.names  #  “None”-> default value of a DataFrame’s index.
# Out:
# FrozenList([None])

# %%
# create a MultiIndex
multi=df.set_index(["Sex","Age"])
multi.head()
# Out:
#              Survived  Pclass  \
# Sex    Age
# male   22.0         0       3
# female 38.0         1       1
#        26.0         1       3
#        35.0         1       1
# male   35.0         0       3
#
#                                                           Name  SibSp  Parch  \
# Sex    Age
# male   22.0                            Braund, Mr. Owen Harris      1      0
# female 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
#        26.0                             Heikkinen, Miss. Laina      0      0
#        35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# male   35.0                           Allen, Mr. William Henry      0      0
#
#                        Ticket     Fare Cabin Embarked
# Sex    Age
# male   22.0         A/5 21171   7.2500   NaN        S
# female 38.0          PC 17599  71.2833   C85        C
#        26.0  STON/O2. 3101282   7.9250   NaN        S
#        35.0            113803  53.1000  C123        S
# ...

# %%
multi.index.names
# Out:
# FrozenList(['Sex', 'Age'])

# %%
multi.index.values # index인 name, sex, age에 대한 정보 출력
# Out:
# array([('male', 22.0), ('female', 38.0), ('female', 26.0),
#        ('female', 35.0), ('male', 35.0), ('male', nan), ('male', 54.0),
#        ('male', 2.0), ('female', 27.0), ('female', 14.0), ('female', 4.0),
#        ('female', 58.0), ('male', 20.0), ('male', 39.0), ('female', 14.0),
#        ('female', 55.0), ('male', 2.0), ('male', nan), ('female', 31.0),
#        ('female', nan), ('male', 35.0), ('male', 34.0), ('female', 15.0),
#        ('male', 28.0), ('female', 8.0), ('female', 38.0), ('male', nan),
#        ('male', 19.0), ('female', nan), ('male', nan), ('male', 40.0),
#        ('female', nan), ('female', nan), ('male', 66.0), ('male', 28.0),
#        ('male', 42.0), ('male', nan), ('male', 21.0), ('female', 18.0),
#        ('female', 14.0), ('female', 40.0), ('female', 27.0),
#        ('male', nan), ('female', 3.0), ('female', 19.0), ('male', nan),
#        ('male', nan), ('female', nan), ('male', nan), ('female', 18.0),
# ...

# %%
# 다시 원래대로
multi.reset_index()
# Out:
#         Sex   Age  Survived  Pclass  \
# 0      male  22.0         0       3
# 1    female  38.0         1       1
# 2    female  26.0         1       3
# 3    female  35.0         1       1
# 4      male  35.0         0       3
# ..      ...   ...       ...     ...
# 886    male  27.0         0       2
# 887  female  19.0         1       1
# 888  female   NaN         0       3
# 889    male  26.0         1       1
# 890    male  32.0         0       3
#
#                                                   Name  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
# 2                               Heikkinen, Miss. Laina      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# 4                             Allen, Mr. William Henry      0      0
# ..                                                 ...    ...    ...
# ...

# %%
multi.head()
# Out:
#              Survived  Pclass  \
# Sex    Age
# male   22.0         0       3
# female 38.0         1       1
#        26.0         1       3
#        35.0         1       1
# male   35.0         0       3
#
#                                                           Name  SibSp  Parch  \
# Sex    Age
# male   22.0                            Braund, Mr. Owen Harris      1      0
# female 38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1      0
#        26.0                             Heikkinen, Miss. Laina      0      0
#        35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1      0
# male   35.0                           Allen, Mr. William Henry      0      0
#
#                        Ticket     Fare Cabin Embarked
# Sex    Age
# male   22.0         A/5 21171   7.2500   NaN        S
# female 38.0          PC 17599  71.2833   C85        C
#        26.0  STON/O2. 3101282   7.9250   NaN        S
#        35.0            113803  53.1000  C123        S
# ...

# %%
# male이면서 35인것을 뽑기

# %%
multi.loc[("male",35.0),:]
# Out:
# C:\Users\yunaj\AppData\Local\Temp\ipykernel_7712\535921786.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   multi.loc[("male",35.0),:]
#            Survived  Pclass                              Name  SibSp  Parch  \
# Sex  Age
# male 35.0         0       3          Allen, Mr. William Henry      0      0
#      35.0         0       2              Fynney, Mr. Joseph J      0      0
#      35.0         0       3                   Asim, Mr. Adola      0      0
#      35.0         0       3              Rintamaki, Mr. Matti      0      0
#      35.0         1       1   Homer, Mr. Harry ("Mr E Haven")      0      0
#      35.0         0       3   Brocklebank, Mr. William Alfred      0      0
#      35.0         1       1  Silverthorne, Mr. Spencer Victor      0      0
#      35.0         1       1            Lesurer, Mr. Gustave J      0      0
#      35.0         0       2         Slemen, Mr. Richard James      0      0
# ...

# %%
multi.loc[("female"),:].head()
# Out:
#       Survived  Pclass                                               Name  \
# Age
# 38.0         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 26.0         1       3                             Heikkinen, Miss. Laina
# 35.0         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 27.0         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 14.0         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       SibSp  Parch            Ticket     Fare Cabin Embarked
# Age
# 38.0      1      0          PC 17599  71.2833   C85        C
# 26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 35.0      1      0            113803  53.1000  C123        S
# 27.0      0      2            347742  11.1333   NaN        S
# 14.0      1      0            237736  30.0708   NaN        C

# %%
# multiindex 만들기
import random
impor

# %%
# 첫번째 방법

# %%
print(type(random.sample(range(1,100),8)))  # list
print(type(np.array(random.sample(range(1,100),8)))) # np로 바꿔줌
np.array(random.sample(range(1,100),8)).shape # 1차원
np.array(random.sample(range(1,100),8)).reshape(4,2) # 2차원
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# array([[40, 33],
#        [60, 31],
#        [53, 11],
#        [ 2, 47]])

# %%
df = pd.DataFrame(np.array(random.sample(range(1,100),8)).reshape(4,2), 
             index=[["연아1","연아1","연아2","연아2"], 
                    ["1학기","2학기", "1학기","2학기"]],
             columns=["수학","영어"])
             
df.head()
# Out:
#          수학  영어
# 연아1 1학기  47  46
#     2학기  65  75
# 연아2 1학기  36  71
#     2학기  56  72

# %%
# 두번째 방법

# %%
pd.Series({("연아1", "수학"):38,
           ("연아1", "영어"):38,
           ("연아2", "수학"):48,
           ("연아2", "영어"):38,
           ("연아3", "수학"):88,
           ("연아3", "영어"):98,   
    
    
})
# Out:
# 연아1  수학    38
#      영어    38
# 연아2  수학    48
#      영어    38
# 연아3  수학    88
#      영어    98
# dtype: int64

# %%
# multiindex 메소드

# %%
df = pd.DataFrame(
    [['Mostly cloudy', 10], ['Sunny', 12]],
    index=['London', 'Oxford'],
    columns=['Weather', 'Wind']
)
df
# Out:
#               Weather  Wind
# London  Mostly cloudy    10
# Oxford          Sunny    12

# %%
df.stack()
# Out:
# London  Weather    Mostly cloudy
#         Wind                  10
# Oxford  Weather            Sunny
#         Wind                  12
# dtype: object
